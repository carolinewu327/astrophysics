# %% [markdown]
# ### GALAXY PAIRS CATALOG

# %%
import numpy as np
import pandas as pd
from astropy.io import fits
from astropy.cosmology import Planck18 as cosmo
from tqdm.notebook import tqdm
from helper import preprocess_catalog_galactic
from helper import load_catalog
from multiprocessing import Pool, cpu_count
from functools import partial

# %%
# --- Settings ---
dataset = "BOSS"
if dataset == "eBOSS":
    catalog, region = "LRG", "NGC"
    real_file = f"data/eBOSS/eBOSS_{catalog}_clustering_data-{region}-vDR16.fits"
    rand_file = f"data/eBOSS/eBOSS_LRG_clustering_random-{region}-vDR16.fits"
elif dataset == "BOSS":
    catalog, region = "CMASS", "North"
    real_file = f"data/BOSS/galaxy_DR12v5_CMASS_{region}.fits"
    rand_file = f"data/BOSS/random0_DR12v5_CMASS_{region}.fits"
else:
    raise ValueError("dataset must be eBOSS or BOSS")

alm_file = "data/COM_Lensing_4096_R3.00/MV/dat_klm.fits"
mask_file = "data/COM_Lensing_4096_R3.00/mask.fits"

# %%
def compute_angle_cosine(l1, b1, l2, b2):
    """
    Compute cosine of angle θ between two directions (in degrees) in Galactic coordinates.
    """
    l1_rad, b1_rad = np.radians(l1), np.radians(b1)
    l2_rad, b2_rad = np.radians(l2), np.radians(b2)

    cos_theta = (
        np.cos(b1_rad) * np.cos(l1_rad) * np.cos(b2_rad) * np.cos(l2_rad) +
        np.cos(b1_rad) * np.sin(l1_rad) * np.cos(b2_rad) * np.sin(l2_rad) +
        np.sin(b1_rad) * np.sin(b2_rad)
    )
    return cos_theta

def galactic_to_cartesian(l, b, D):
    """
    Convert Galactic coordinates (l, b in degrees, D in Mpc/h) to 3D Cartesian.
    """
    l_rad, b_rad = np.radians(l), np.radians(b)
    x = D * np.cos(b_rad) * np.cos(l_rad)
    y = D * np.cos(b_rad) * np.sin(l_rad)
    z = D * np.sin(b_rad)
    return np.column_stack([x, y, z])

def create_distance_bins(D, r_par_max):
    """
    Create bins for parallel distance (comoving distance) to limit search space.
    """
    # Sort galaxies by distance and create bins
    sorted_indices = np.argsort(D)
    sorted_D = D[sorted_indices]
    
    # Create bins with width = r_par_max to limit parallel distance searches
    bins = {}
    current_bin = 0
    bin_edges = [0]
    
    for i, d in enumerate(sorted_D):
        if i == 0 or d - sorted_D[bin_edges[-1]] > r_par_max * 2:
            bin_edges.append(i)
            current_bin += 1
    
    bin_edges.append(len(D))
    
    # Store which galaxies are in searchable range for each bin
    for i in range(len(bin_edges) - 1):
        bin_start = bin_edges[i]
        bin_end = bin_edges[i + 1]
        bins[i] = sorted_indices[bin_start:bin_end]
    
    return bins, sorted_indices, sorted_D

def process_chunk_optimized(chunk_start_end, l, b, D, data_filtered, weights_valid, z, 
                            r_par_max, r_perp_min, r_perp_max, sorted_indices, sorted_D):
    """
    Process a chunk of galaxies using VECTORIZED distance-sorted approach.
    This is MUCH faster than the loop version.
    """
    import time
    chunk_start, chunk_end = chunk_start_end
    
    # Pre-allocate lists for vectorized operations
    i_list, j_list = [], []
    Dc1_list, Dc2_list = [], []
    
    start_time = time.time()
    last_print_time = start_time
    
    # First pass: collect candidate pairs using fast filtering
    for idx in range(chunk_start, chunk_end):
        i = sorted_indices[idx]
        Dc1 = D[i]
        
        # Debug: print progress every 1000 galaxies
        if (idx - chunk_start) > 0 and (idx - chunk_start) % 1000 == 0:
            current_time = time.time()
            elapsed = current_time - start_time
            interval_time = current_time - last_print_time
            galaxies_processed = idx - chunk_start
            rate = 1000 / interval_time if interval_time > 0 else 0
            pairs_found = len(i_list)
            print(f"  Chunk [{chunk_start}-{chunk_end}]: Processed {galaxies_processed}/{chunk_end-chunk_start} galaxies "
                  f"({rate:.1f} gal/s, {interval_time:.1f}s for last 1000, {pairs_found} pairs so far)")
            last_print_time = current_time
        
        # Binary search for galaxies within r_par_max
        left_bound = np.searchsorted(sorted_D, Dc1 - r_par_max, side='left')
        right_bound = np.searchsorted(sorted_D, Dc1 + r_par_max, side='right')
        search_start = max(idx + 1, left_bound)
        search_end = right_bound
        
        if search_end <= search_start:
            continue
        
        # Get all candidate j indices
        j_candidates = sorted_indices[search_start:search_end]
        Dc2_candidates = D[j_candidates]
        
        # Vectorized angular filtering
        l1, b1 = l[i], b[i]
        l2_candidates = l[j_candidates]
        b2_candidates = b[j_candidates]
        
        # Fast approximate angular separation
        dl = np.abs(l2_candidates - l1)
        db = np.abs(b2_candidates - b1)
        
        # Handle wrapping around 360 degrees for longitude
        dl = np.minimum(dl, 360 - dl)
        
        D_avg = (Dc1 + Dc2_candidates) / 2.0
        min_angle = r_perp_min / D_avg
        max_angle = r_perp_max / D_avg

        # apply cosb correction for proper angular separation approximation
        # without this, rough_angle overestimates true angle at hih latitidues, potentiallu causing valid pairs to be missed
        cosb1 = np.cos(np.radians(b1))
        rough_angle = np.sqrt((np.radians(dl*cosb1))**2 + (np.radians(db))**2)
        
        # Filter by approximate angle (with generous margins)
        angle_mask = (rough_angle >= min_angle * 0.7) & (rough_angle <= max_angle * 2)
        
        if not np.any(angle_mask):
            continue
        
        # Keep only candidates that pass angular filter
        j_filtered = j_candidates[angle_mask]
        
        # Store for vectorized processing
        i_list.extend([i] * len(j_filtered))
        j_list.extend(j_filtered)
    
    if len(i_list) == 0:
        return []
    
    # Convert to arrays for vectorized computation
    i_arr = np.array(i_list)
    j_arr = np.array(j_list)
    
    # Vectorized precise angle calculation
    l1_arr, b1_arr = l[i_arr], b[i_arr]
    l2_arr, b2_arr = l[j_arr], b[j_arr]
    
    l1_rad, b1_rad = np.radians(l1_arr), np.radians(b1_arr)
    l2_rad, b2_rad = np.radians(l2_arr), np.radians(b2_arr)
    
    cos_theta = (
        np.cos(b1_rad) * np.cos(l1_rad) * np.cos(b2_rad) * np.cos(l2_rad) +
        np.cos(b1_rad) * np.sin(l1_rad) * np.cos(b2_rad) * np.sin(l2_rad) +
        np.sin(b1_rad) * np.sin(b2_rad)
    )
    
    theta = np.arccos(np.clip(cos_theta, -1, 1))
    
    Dc1_arr = D[i_arr]
    Dc2_arr = D[j_arr]
    D_avg_arr = (Dc1_arr + Dc2_arr) / 2.0
    r_perp_arr = D_avg_arr * theta
    
    # Final filter
    final_mask = (r_perp_arr >= r_perp_min) & (r_perp_arr <= r_perp_max)
    
    # Build pairs for accepted candidates
    i_final = i_arr[final_mask]
    j_final = j_arr[final_mask]
    
    pairs = []
    for idx in range(len(i_final)):
        i = i_final[idx]
        j = j_final[idx]
        Dmid = cosmo.comoving_distance((z[i] + z[j]) / 2).value * cosmo.h
        pairs.append({
            'l1': l[i], 'b1': b[i], 'z1': z[i], 'w1': weights_valid[i], 'Dc1': D[i], 'ID1': data_filtered[i]['ID'],
            'l2': l[j], 'b2': b[j], 'z2': z[j], 'w2': weights_valid[j], 'Dc2': D[j], 'ID2': data_filtered[j]['ID'],
            'Dmid': Dmid
        })
    
    total_time = time.time() - start_time
    print(f"  Chunk [{chunk_start}-{chunk_end}] COMPLETE: {chunk_end-chunk_start} galaxies in {total_time:.1f}s, found {len(pairs)} pairs")
    
    return pairs

def build_galaxy_pair_catalog(data, weights, r_par_max=20, r_perp_min=18, r_perp_max=22,
                               n_processes=None, chunk_size=10000, save_intermediate=True):
    """
    Build galaxy pair catalog based on parallel and perpendicular distance criteria.
    Uses distance sorting and VECTORIZED operations for maximum speed.
    
    Parameters:
    -----------
    data : array
        Galaxy catalog data
    weights : array
        Galaxy weights
    r_par_max : float
        Maximum parallel distance (Mpc/h)
    r_perp_min : float
        Minimum perpendicular distance (Mpc/h)
    r_perp_max : float
        Maximum perpendicular distance (Mpc/h)
    n_processes : int or None
        Number of processes to use (default: cpu_count() - 1)
    chunk_size : int
        Number of galaxies to process per chunk
    save_intermediate : bool
        Save results every 10 chunks to avoid losing progress
    
    Returns:
    --------
    pairs : DataFrame
        Galaxy pair catalog
    """
    l, b, D, data_filtered, weights_valid = preprocess_catalog_galactic(data, weights)
    z = data_filtered['Z']
    
    n_galaxies = len(data_filtered)
    print(f"Building pair catalog for {n_galaxies} galaxies...")
    print(f"Search parameters: r_par_max={r_par_max}, r_perp_min={r_perp_min}, r_perp_max={r_perp_max}")
    
    # Sort galaxies by distance for efficient searching
    print("Sorting galaxies by comoving distance...")
    sorted_indices = np.argsort(D)
    sorted_D = D[sorted_indices]
    
    # Estimate search space
    avg_D = np.median(D)
    expected_pairs_per_galaxy = int((2 * r_par_max / avg_D) * n_galaxies * 0.01)
    print(f"Average distance: {avg_D:.1f} Mpc/h")
    print(f"Estimated search space per galaxy: ~{expected_pairs_per_galaxy} candidates")
    
    # Split into chunks for parallel processing
    n_chunks = int(np.ceil(n_galaxies / chunk_size))
    chunk_ranges = [(i * chunk_size, min((i + 1) * chunk_size, n_galaxies)) 
                    for i in range(n_chunks)]
    
    if n_processes is None:
        # Use 75% of available cores (better for Windows and memory usage)
        n_processes = max(1, int(cpu_count() * 0.75))
    
    # Cap at reasonable maximum (too many processes = overhead + memory issues)
    n_processes = min(n_processes, 12)
    
    print(f"Processing {n_chunks} chunks using {n_processes} processes...")
    print(f"NOTE: With r_perp_min={r_perp_min}, you may find MANY pairs. Consider r_perp_min > 5-10.")
    
    # Create partial function with fixed parameters
    process_func = partial(
        process_chunk_optimized,
        l=l, b=b, D=D, 
        data_filtered=data_filtered, weights_valid=weights_valid, z=z,
        r_par_max=r_par_max, r_perp_min=r_perp_min, r_perp_max=r_perp_max,
        sorted_indices=sorted_indices, sorted_D=sorted_D
    )
    
    # Process in parallel with intermediate saves
    all_pairs = []
    output_file = f"data/paircatalogs/galaxy_pairs_catalog_CMASS_{region}_{r_par_max}_{r_perp_min}_{r_perp_max}hmpc.csv"
    
    if n_processes > 1:
        import time
        print(f"\n{'='*60}")
        print(f"NOTE: Debug prints from worker processes won't appear here.")
        print(f"Progress tracked by main process after each chunk completes.")
        print(f"{'='*60}\n")
        
        chunk_start_time = time.time()
        with Pool(processes=n_processes) as pool:
            for i, result in enumerate(tqdm(
                pool.imap(process_func, chunk_ranges),
                total=len(chunk_ranges),
                desc="Finding pairs"
            )):
                chunk_time = time.time() - chunk_start_time
                all_pairs.extend(result)
                
                # Print summary after each chunk completes
                chunk_start, chunk_end = chunk_ranges[i]
                n_pairs_in_chunk = len(result)
                total_pairs_so_far = sum(len(p) if isinstance(p, list) else 1 for p in all_pairs)
                print(f"\n  Chunk {i+1}/{len(chunk_ranges)} [{chunk_start}-{chunk_end}]: "
                      f"Found {n_pairs_in_chunk:,} pairs in {chunk_time:.1f}s "
                      f"({(chunk_end-chunk_start)/chunk_time:.1f} gal/s) | "
                      f"Total: {total_pairs_so_far:,} pairs")
                
                # Save intermediate results every 10 chunks
                if save_intermediate and (i + 1) % 10 == 0:
                    temp_df = pd.DataFrame([p for chunk in all_pairs for p in [chunk]] if isinstance(all_pairs[0], dict) else all_pairs)
                    temp_file = output_file.replace('.csv', f'_temp_{i+1}.csv')
                    temp_df.to_csv(temp_file, index=False)
                    print(f"  ✓ Checkpoint: Saved {len(temp_df):,} pairs to {temp_file}")
                
                chunk_start_time = time.time()
    else:
        # Single process mode - debug prints WILL appear
        print(f"\n{'='*60}")
        print(f"Running in SINGLE PROCESS mode - all debug prints visible.")
        print(f"{'='*60}\n")
        
        for i, chunk in enumerate(tqdm(chunk_ranges, desc="Finding pairs")):
            result = process_func(chunk)
            all_pairs.extend(result)
            
            if save_intermediate and (i + 1) % 10 == 0:
                temp_df = pd.DataFrame(all_pairs)
                temp_file = output_file.replace('.csv', f'_temp_{i+1}.csv')
                temp_df.to_csv(temp_file, index=False)
                print(f"\n  Checkpoint: Saved {len(temp_df)} pairs to {temp_file}")
    
    # Flatten and convert to DataFrame
    pairs = [pair for chunk_pairs in all_pairs for pair in chunk_pairs] if all_pairs and isinstance(all_pairs[0], list) else all_pairs
    
    print(f"\nFound {len(pairs)} total pairs")
    
    pairs_df = pd.DataFrame(pairs)
    pairs_df.to_csv(output_file, index=False)
    print(f"Saved to {output_file}")
    
    return pairs_df

# %%
# --- Run all ---
if dataset == "BOSS":
    z_min = .4
    z_max = .7
    weight = "CMASS"
else: # eBOSS
    z_min = 0
    z_max = 10000
    weight = True

data_real, w_real = load_catalog(real_file, weights=weight, z_min=z_min, z_max=z_max)
# data_rand, w_rand = load_catalog(rand_file, random_fraction=0.10)

# Build galaxy pair catalog with VECTORIZED version
# This eliminates inner Python loops for massive speedup
pair_catalog = build_galaxy_pair_catalog(
    data_real, w_real, 
    r_par_max=20,
    r_perp_min=18,          # NOTE: r_perp_min=0 will find MANY pairs! Consider 5-10 for faster results
    r_perp_max=22,
    n_processes=1,      # Auto: uses 75% of cores (capped at 12). On 16-core: will use 12
    chunk_size=10000,      # Even larger chunks with vectorization
    save_intermediate=True # Saves progress every 10 chunks
)
print(f"Total valid pairs: {len(pair_catalog)}")

# Jackknife real galaxies
# kappa_real, sigma_real = jackknife_stack_healpix(data_real, w_real, data_rand, nside=10)
# sn_real = np.zeros_like(kappa_real)
# valid = sigma_real > 0
# sn_real[valid] = kappa_real[valid] / sigma_real[valid]
# kappa_rand, sigma_rand, sn_rand = stack_kappa(data_rand, w_rand, "Random")
# kappa_sub = kappa_real - kappa_rand
# kappa_smooth = gaussian_filter(kappa_sub, sigma=2)
# Out:
# Building pair catalog for 579089 galaxies...
# Search parameters: r_par_max=20, r_perp_min=18, r_perp_max=22
# Sorting galaxies by comoving distance...
# Average distance: 1405.2 Mpc/h
# Estimated search space per galaxy: ~164 candidates
# Processing 58 chunks using 1 processes...
# NOTE: With r_perp_min=18, you may find MANY pairs. Consider r_perp_min > 5-10.
#
# ============================================================
# Running in SINGLE PROCESS mode - all debug prints visible.
# ============================================================
# Finding pairs:   0%|          | 0/58 [00:00<?, ?it/s]
#   Chunk [0-10000]: Processed 1000/10000 galaxies (12180.4 gal/s, 0.1s for last 1000, 4201 pairs so far)
#   Chunk [0-10000]: Processed 2000/10000 galaxies (13153.6 gal/s, 0.1s for last 1000, 9490 pairs so far)
#   Chunk [0-10000]: Processed 3000/10000 galaxies (8448.4 gal/s, 0.1s for last 1000, 15388 pairs so far)
#   Chunk [0-10000]: Processed 4000/10000 galaxies (18246.5 gal/s, 0.1s for last 1000, 22339 pairs so far)
#   Chunk [0-10000]: Processed 5000/10000 galaxies (15525.1 gal/s, 0.1s for last 1000, 30406 pairs so far)
#   Chunk [0-10000]: Processed 6000/10000 galaxies (13501.3 gal/s, 0.1s for last 1000, 39564 pairs so far)
#   Chunk [0-10000]: Processed 7000/10000 galaxies (14566.0 gal/s, 0.1s for last 1000, 49739 pairs so far)
#   Chunk [0-10000]: Processed 8000/10000 galaxies (12135.0 gal/s, 0.1s for last 1000, 60873 pairs so far)
#   Chunk [0-10000]: Processed 9000/10000 galaxies (9305.4 gal/s, 0.1s for last 1000, 72578 pairs so far)
#   Chunk [0-10000] COMPLETE: 10000 galaxies in 1.2s, found 8334 pairs
#   Chunk [10000-20000]: Processed 1000/10000 galaxies (11880.4 gal/s, 0.1s for last 1000, 13809 pairs so far)
#   Chunk [10000-20000]: Processed 2000/10000 galaxies (12492.8 gal/s, 0.1s for last 1000, 28416 pairs so far)
#   Chunk [10000-20000]: Processed 3000/10000 galaxies (11267.5 gal/s, 0.1s for last 1000, 44010 pairs so far)
#   Chunk [30000-40000] COMPLETE: 10000 galaxies in 2.8s, found 29181 pairs
#   Chunk [40000-50000]: Processed 1000/10000 galaxies (4468.7 gal/s, 0.2s for last 1000, 32019 pairs so far)
#   Chunk [40000-50000]: Processed 2000/10000 galaxies (6078.2 gal/s, 0.2s for last 1000, 64461 pairs so far)
#   Chunk [40000-50000]: Processed 3000/10000 galaxies (6193.6 gal/s, 0.2s for last 1000, 96533 pairs so far)
#   Chunk [40000-50000]: Processed 4000/10000 galaxies (6279.4 gal/s, 0.2s for last 1000, 129287 pairs so far)
#   Chunk [40000-50000]: Processed 5000/10000 galaxies (5953.2 gal/s, 0.2s for last 1000, 162940 pairs so far)
#   Chunk [40000-50000]: Processed 6000/10000 galaxies (5558.6 gal/s, 0.2s for last 1000, 195640 pairs so far)
#   Chunk [40000-50000]: Processed 7000/10000 galaxies (5855.9 gal/s, 0.2s for last 1000, 228976 pairs so far)
#   Chunk [40000-50000]: Processed 8000/10000 galaxies (5816.4 gal/s, 0.2s for last 1000, 263092 pairs so far)
#   Chunk [40000-50000]: Processed 9000/10000 galaxies (5482.5 gal/s, 0.2s for last 1000, 296362 pairs so far)
#   Chunk [40000-50000] COMPLETE: 10000 galaxies in 3.2s, found 32728 pairs
#   Chunk [50000-60000]: Processed 1000/10000 galaxies (4760.0 gal/s, 0.2s for last 1000, 33947 pairs so far)
#   Chunk [50000-60000]: Processed 2000/10000 galaxies (5738.9 gal/s, 0.2s for last 1000, 68491 pairs so far)
#   Chunk [50000-60000]: Processed 3000/10000 galaxies (5588.9 gal/s, 0.2s for last 1000, 103219 pairs so far)
#   Chunk [50000-60000]: Processed 4000/10000 galaxies (5418.6 gal/s, 0.2s for last 1000, 140180 pairs so far)
#   Chunk [50000-60000]: Processed 5000/10000 galaxies (5266.0 gal/s, 0.2s for last 1000, 176810 pairs so far)
#   Chunk [50000-60000]: Processed 6000/10000 galaxies (5139.9 gal/s, 0.2s for last 1000, 214177 pairs so far)
#   Chunk [50000-60000]: Processed 7000/10000 galaxies (3971.3 gal/s, 0.3s for last 1000, 252140 pairs so far)
#   Chunk [50000-60000]: Processed 8000/10000 galaxies (5407.1 gal/s, 0.2s for last 1000, 290184 pairs so far)
#   Chunk [50000-60000]: Processed 9000/10000 galaxies (5143.8 gal/s, 0.2s for last 1000, 327802 pairs so far)
#   Chunk [50000-60000] COMPLETE: 10000 galaxies in 3.3s, found 35969 pairs
#   Chunk [60000-70000]: Processed 1000/10000 galaxies (4482.6 gal/s, 0.2s for last 1000, 37601 pairs so far)
#   Chunk [60000-70000]: Processed 2000/10000 galaxies (4979.5 gal/s, 0.2s for last 1000, 75448 pairs so far)
#   Chunk [60000-70000]: Processed 3000/10000 galaxies (4794.7 gal/s, 0.2s for last 1000, 115351 pairs so far)
#   Chunk [60000-70000]: Processed 4000/10000 galaxies (3132.7 gal/s, 0.3s for last 1000, 154766 pairs so far)
#   Chunk [60000-70000]: Processed 5000/10000 galaxies (3060.7 gal/s, 0.3s for last 1000, 194083 pairs so far)
#   Chunk [220000-230000]: Processed 1000/10000 galaxies (2867.5 gal/s, 0.3s for last 1000, 43121 pairs so far)
#   Chunk [220000-230000]: Processed 2000/10000 galaxies (3568.7 gal/s, 0.3s for last 1000, 85433 pairs so far)
#   Chunk [220000-230000]: Processed 3000/10000 galaxies (3909.8 gal/s, 0.3s for last 1000, 126622 pairs so far)
#   Chunk [220000-230000]: Processed 4000/10000 galaxies (3746.0 gal/s, 0.3s for last 1000, 169840 pairs so far)
#   Chunk [220000-230000]: Processed 5000/10000 galaxies (3871.7 gal/s, 0.3s for last 1000, 212780 pairs so far)
#   Chunk [220000-230000]: Processed 6000/10000 galaxies (3910.0 gal/s, 0.3s for last 1000, 254712 pairs so far)
#   Chunk [220000-230000]: Processed 7000/10000 galaxies (3888.3 gal/s, 0.3s for last 1000, 296508 pairs so far)
#   Chunk [220000-230000]: Processed 8000/10000 galaxies (3806.7 gal/s, 0.3s for last 1000, 339968 pairs so far)
#   Chunk [220000-230000]: Processed 9000/10000 galaxies (3903.5 gal/s, 0.3s for last 1000, 382787 pairs so far)
#   Chunk [220000-230000] COMPLETE: 10000 galaxies in 4.3s, found 41938 pairs
#   Chunk [230000-240000]: Processed 1000/10000 galaxies (2721.0 gal/s, 0.4s for last 1000, 44032 pairs so far)
#   Chunk [230000-240000]: Processed 2000/10000 galaxies (3445.6 gal/s, 0.3s for last 1000, 85632 pairs so far)
#   Chunk [230000-240000]: Processed 3000/10000 galaxies (3615.7 gal/s, 0.3s for last 1000, 127348 pairs so far)
#   Chunk [230000-240000]: Processed 4000/10000 galaxies (3762.1 gal/s, 0.3s for last 1000, 169600 pairs so far)
#   Chunk [230000-240000]: Processed 5000/10000 galaxies (3752.5 gal/s, 0.3s for last 1000, 211565 pairs so far)
#   Chunk [230000-240000]: Processed 6000/10000 galaxies (3665.3 gal/s, 0.3s for last 1000, 254114 pairs so far)
#   Chunk [230000-240000]: Processed 7000/10000 galaxies (3764.3 gal/s, 0.3s for last 1000, 296462 pairs so far)
#   Chunk [230000-240000]: Processed 8000/10000 galaxies (3752.4 gal/s, 0.3s for last 1000, 337844 pairs so far)
#   Chunk [230000-240000]: Processed 9000/10000 galaxies (3761.5 gal/s, 0.3s for last 1000, 379636 pairs so far)
#   Chunk [230000-240000] COMPLETE: 10000 galaxies in 4.4s, found 41224 pairs
#   Chunk [240000-250000]: Processed 1000/10000 galaxies (3006.2 gal/s, 0.3s for last 1000, 43173 pairs so far)
#   Chunk [240000-250000]: Processed 2000/10000 galaxies (3767.2 gal/s, 0.3s for last 1000, 85264 pairs so far)
#   Chunk [240000-250000]: Processed 3000/10000 galaxies (3717.8 gal/s, 0.3s for last 1000, 128094 pairs so far)
#   Chunk [240000-250000]: Processed 4000/10000 galaxies (3768.4 gal/s, 0.3s for last 1000, 170365 pairs so far)
#   Chunk [240000-250000]: Processed 5000/10000 galaxies (2988.5 gal/s, 0.3s for last 1000, 213941 pairs so far)
#   Chunk [240000-250000]: Processed 6000/10000 galaxies (3582.0 gal/s, 0.3s for last 1000, 256470 pairs so far)
#   Chunk [240000-250000]: Processed 7000/10000 galaxies (3736.2 gal/s, 0.3s for last 1000, 299847 pairs so far)
#   Chunk [240000-250000]: Processed 8000/10000 galaxies (3751.3 gal/s, 0.3s for last 1000, 341359 pairs so far)
#   Chunk [240000-250000]: Processed 9000/10000 galaxies (3746.5 gal/s, 0.3s for last 1000, 383256 pairs so far)
#   Chunk [240000-250000] COMPLETE: 10000 galaxies in 4.6s, found 41468 pairs
#   Chunk [250000-260000]: Processed 1000/10000 galaxies (3096.3 gal/s, 0.3s for last 1000, 43451 pairs so far)
#   Chunk [250000-260000]: Processed 2000/10000 galaxies (3595.9 gal/s, 0.3s for last 1000, 85878 pairs so far)
#   Chunk [250000-260000]: Processed 3000/10000 galaxies (3808.8 gal/s, 0.3s for last 1000, 128668 pairs so far)
#   Chunk [250000-260000]: Processed 4000/10000 galaxies (3850.0 gal/s, 0.3s for last 1000, 170837 pairs so far)
#   Chunk [250000-260000]: Processed 5000/10000 galaxies (3862.0 gal/s, 0.3s for last 1000, 212217 pairs so far)
#   Chunk [250000-260000]: Processed 6000/10000 galaxies (3862.7 gal/s, 0.3s for last 1000, 252885 pairs so far)
#   Chunk [250000-260000]: Processed 7000/10000 galaxies (3853.3 gal/s, 0.3s for last 1000, 294356 pairs so far)
#   Chunk [250000-260000]: Processed 8000/10000 galaxies (3861.5 gal/s, 0.3s for last 1000, 336057 pairs so far)
#   Chunk [250000-260000]: Processed 9000/10000 galaxies (3834.2 gal/s, 0.3s for last 1000, 376871 pairs so far)
#   Chunk [250000-260000] COMPLETE: 10000 galaxies in 4.2s, found 40502 pairs
#   Chunk [260000-270000]: Processed 1000/10000 galaxies (3078.2 gal/s, 0.3s for last 1000, 41376 pairs so far)
#   Chunk [260000-270000]: Processed 2000/10000 galaxies (3627.8 gal/s, 0.3s for last 1000, 82011 pairs so far)
#   Chunk [260000-270000]: Processed 3000/10000 galaxies (3723.3 gal/s, 0.3s for last 1000, 122510 pairs so far)
#   Chunk [260000-270000]: Processed 4000/10000 galaxies (3825.2 gal/s, 0.3s for last 1000, 163859 pairs so far)
#   Chunk [260000-270000]: Processed 5000/10000 galaxies (3835.3 gal/s, 0.3s for last 1000, 204546 pairs so far)
#   Chunk [260000-270000]: Processed 6000/10000 galaxies (3764.6 gal/s, 0.3s for last 1000, 243937 pairs so far)
#   Chunk [260000-270000]: Processed 7000/10000 galaxies (3874.0 gal/s, 0.3s for last 1000, 285229 pairs so far)
#   Chunk [260000-270000]: Processed 8000/10000 galaxies (3837.6 gal/s, 0.3s for last 1000, 326054 pairs so far)
#   Chunk [260000-270000]: Processed 9000/10000 galaxies (3846.1 gal/s, 0.3s for last 1000, 365778 pairs so far)
#   Chunk [260000-270000] COMPLETE: 10000 galaxies in 4.4s, found 40133 pairs
#   Chunk [270000-280000]: Processed 1000/10000 galaxies (3218.6 gal/s, 0.3s for last 1000, 40197 pairs so far)
#   Chunk [270000-280000]: Processed 2000/10000 galaxies (3743.3 gal/s, 0.3s for last 1000, 80080 pairs so far)
#   Chunk [420000-430000]: Processed 7000/10000 galaxies (4961.2 gal/s, 0.2s for last 1000, 178963 pairs so far)
#   Chunk [420000-430000]: Processed 8000/10000 galaxies (5086.0 gal/s, 0.2s for last 1000, 204129 pairs so far)
#   Chunk [420000-430000]: Processed 9000/10000 galaxies (4792.1 gal/s, 0.2s for last 1000, 229474 pairs so far)
#   Chunk [420000-430000] COMPLETE: 10000 galaxies in 2.9s, found 25070 pairs
#   Chunk [430000-440000]: Processed 1000/10000 galaxies (4413.3 gal/s, 0.2s for last 1000, 25040 pairs so far)
#   Chunk [430000-440000]: Processed 2000/10000 galaxies (4990.6 gal/s, 0.2s for last 1000, 50388 pairs so far)
#   Chunk [430000-440000]: Processed 3000/10000 galaxies (4894.9 gal/s, 0.2s for last 1000, 75703 pairs so far)
#   Chunk [430000-440000]: Processed 4000/10000 galaxies (5015.3 gal/s, 0.2s for last 1000, 100122 pairs so far)
#   Chunk [430000-440000]: Processed 5000/10000 galaxies (4921.6 gal/s, 0.2s for last 1000, 125666 pairs so far)
#   Chunk [430000-440000]: Processed 6000/10000 galaxies (5133.9 gal/s, 0.2s for last 1000, 150397 pairs so far)
#   Chunk [430000-440000]: Processed 7000/10000 galaxies (4890.7 gal/s, 0.2s for last 1000, 174651 pairs so far)
#   Chunk [430000-440000]: Processed 8000/10000 galaxies (5202.7 gal/s, 0.2s for last 1000, 198655 pairs so far)
#   Chunk [430000-440000]: Processed 9000/10000 galaxies (5233.5 gal/s, 0.2s for last 1000, 222841 pairs so far)
#   Chunk [430000-440000] COMPLETE: 10000 galaxies in 2.8s, found 24211 pairs
#   Chunk [440000-450000]: Processed 1000/10000 galaxies (5219.9 gal/s, 0.2s for last 1000, 23817 pairs so far)
#   Chunk [440000-450000]: Processed 2000/10000 galaxies (5167.7 gal/s, 0.2s for last 1000, 47657 pairs so far)
#   Chunk [440000-450000]: Processed 3000/10000 galaxies (5299.9 gal/s, 0.2s for last 1000, 71008 pairs so far)
#   Chunk [440000-450000]: Processed 4000/10000 galaxies (5247.4 gal/s, 0.2s for last 1000, 94490 pairs so far)
#   Chunk [440000-450000]: Processed 5000/10000 galaxies (5510.7 gal/s, 0.2s for last 1000, 118556 pairs so far)
#   Chunk [440000-450000]: Processed 6000/10000 galaxies (5426.4 gal/s, 0.2s for last 1000, 142004 pairs so far)
#   Chunk [440000-450000]: Processed 7000/10000 galaxies (5542.5 gal/s, 0.2s for last 1000, 165179 pairs so far)
#   Chunk [440000-450000]: Processed 8000/10000 galaxies (5407.0 gal/s, 0.2s for last 1000, 189242 pairs so far)
#   Chunk [440000-450000]: Processed 9000/10000 galaxies (5588.6 gal/s, 0.2s for last 1000, 212531 pairs so far)
#   Chunk [440000-450000] COMPLETE: 10000 galaxies in 2.6s, found 23065 pairs
#   Chunk [450000-460000]: Processed 1000/10000 galaxies (5194.8 gal/s, 0.2s for last 1000, 22867 pairs so far)
#   Chunk [450000-460000]: Processed 2000/10000 galaxies (5456.0 gal/s, 0.2s for last 1000, 45952 pairs so far)
#   Chunk [450000-460000]: Processed 3000/10000 galaxies (5736.0 gal/s, 0.2s for last 1000, 69033 pairs so far)
#   Chunk [450000-460000]: Processed 4000/10000 galaxies (5663.2 gal/s, 0.2s for last 1000, 91718 pairs so far)
#   Chunk [450000-460000]: Processed 5000/10000 galaxies (5603.7 gal/s, 0.2s for last 1000, 114678 pairs so far)
#   Chunk [450000-460000]: Processed 6000/10000 galaxies (5637.5 gal/s, 0.2s for last 1000, 137067 pairs so far)
#   Chunk [450000-460000]: Processed 7000/10000 galaxies (5851.5 gal/s, 0.2s for last 1000, 159421 pairs so far)
#   Chunk [450000-460000]: Processed 8000/10000 galaxies (5609.6 gal/s, 0.2s for last 1000, 181919 pairs so far)
#   Chunk [450000-460000]: Processed 9000/10000 galaxies (5866.2 gal/s, 0.2s for last 1000, 204025 pairs so far)
#   Chunk [450000-460000] COMPLETE: 10000 galaxies in 2.6s, found 22552 pairs
#   Chunk [460000-470000]: Processed 1000/10000 galaxies (5549.6 gal/s, 0.2s for last 1000, 21043 pairs so far)
#   Chunk [460000-470000]: Processed 2000/10000 galaxies (5534.6 gal/s, 0.2s for last 1000, 42341 pairs so far)
#   Chunk [460000-470000]: Processed 3000/10000 galaxies (5620.9 gal/s, 0.2s for last 1000, 63452 pairs so far)
#   Chunk [460000-470000]: Processed 4000/10000 galaxies (5428.9 gal/s, 0.2s for last 1000, 84211 pairs so far)
#   Chunk [460000-470000]: Processed 5000/10000 galaxies (5690.4 gal/s, 0.2s for last 1000, 104915 pairs so far)
#   Chunk [460000-470000]: Processed 6000/10000 galaxies (5701.5 gal/s, 0.2s for last 1000, 125691 pairs so far)
#   Chunk [460000-470000]: Processed 7000/10000 galaxies (5953.3 gal/s, 0.2s for last 1000, 146135 pairs so far)
#   Chunk [460000-470000]: Processed 8000/10000 galaxies (5854.8 gal/s, 0.2s for last 1000, 166419 pairs so far)
#   Chunk [460000-470000]: Processed 9000/10000 galaxies (5863.6 gal/s, 0.2s for last 1000, 186729 pairs so far)
#   Chunk [460000-470000] COMPLETE: 10000 galaxies in 2.5s, found 20580 pairs
#   Chunk [470000-480000]: Processed 1000/10000 galaxies (5284.6 gal/s, 0.2s for last 1000, 19999 pairs so far)
#   Chunk [470000-480000]: Processed 2000/10000 galaxies (5810.5 gal/s, 0.2s for last 1000, 39673 pairs so far)
#   Chunk [470000-480000]: Processed 3000/10000 galaxies (5971.3 gal/s, 0.2s for last 1000, 59875 pairs so far)
#   Chunk [470000-480000]: Processed 4000/10000 galaxies (6050.3 gal/s, 0.2s for last 1000, 79722 pairs so far)
#   Chunk [470000-480000]: Processed 5000/10000 galaxies (6184.7 gal/s, 0.2s for last 1000, 98984 pairs so far)
#   Chunk [470000-480000]: Processed 6000/10000 galaxies (5761.6 gal/s, 0.2s for last 1000, 118749 pairs so far)
#   Chunk [470000-480000]: Processed 7000/10000 galaxies (6107.5 gal/s, 0.2s for last 1000, 138384 pairs so far)
#   Chunk [470000-480000]: Processed 8000/10000 galaxies (6152.3 gal/s, 0.2s for last 1000, 157603 pairs so far)
#   Chunk [470000-480000]: Processed 9000/10000 galaxies (6038.1 gal/s, 0.2s for last 1000, 177194 pairs so far)
#   Chunk [470000-480000] COMPLETE: 10000 galaxies in 2.3s, found 19369 pairs
#   Chunk [480000-490000]: Processed 1000/10000 galaxies (5695.5 gal/s, 0.2s for last 1000, 18875 pairs so far)
#   Chunk [480000-490000]: Processed 2000/10000 galaxies (5917.2 gal/s, 0.2s for last 1000, 38137 pairs so far)
#   Chunk [480000-490000]: Processed 3000/10000 galaxies (6186.8 gal/s, 0.2s for last 1000, 57222 pairs so far)
#   Chunk [480000-490000]: Processed 4000/10000 galaxies (6224.2 gal/s, 0.2s for last 1000, 75766 pairs so far)
#   Chunk [480000-490000]: Processed 5000/10000 galaxies (6295.6 gal/s, 0.2s for last 1000, 94493 pairs so far)
#   Chunk [480000-490000]: Processed 6000/10000 galaxies (6155.4 gal/s, 0.2s for last 1000, 113189 pairs so far)
#   Chunk [480000-490000]: Processed 7000/10000 galaxies (6413.3 gal/s, 0.2s for last 1000, 131604 pairs so far)
#   Chunk [480000-490000]: Processed 8000/10000 galaxies (6154.4 gal/s, 0.2s for last 1000, 149639 pairs so far)
#   Chunk [480000-490000]: Processed 9000/10000 galaxies (6409.1 gal/s, 0.2s for last 1000, 167205 pairs so far)
#   Chunk [480000-490000] COMPLETE: 10000 galaxies in 2.2s, found 18109 pairs
#   Chunk [490000-500000]: Processed 1000/10000 galaxies (6154.6 gal/s, 0.2s for last 1000, 17276 pairs so far)
#   Chunk [490000-500000]: Processed 2000/10000 galaxies (6202.3 gal/s, 0.2s for last 1000, 34492 pairs so far)
#   Chunk [490000-500000]: Processed 3000/10000 galaxies (6186.9 gal/s, 0.2s for last 1000, 51236 pairs so far)
#   Chunk [490000-500000]: Processed 4000/10000 galaxies (6269.8 gal/s, 0.2s for last 1000, 67994 pairs so far)
#   Chunk [490000-500000]: Processed 5000/10000 galaxies (6535.7 gal/s, 0.2s for last 1000, 84642 pairs so far)
#   Chunk [490000-500000]: Processed 6000/10000 galaxies (6573.0 gal/s, 0.2s for last 1000, 101119 pairs so far)
#   Chunk [490000-500000]: Processed 7000/10000 galaxies (6464.1 gal/s, 0.2s for last 1000, 117557 pairs so far)
#   Chunk [490000-500000]: Processed 8000/10000 galaxies (6838.1 gal/s, 0.1s for last 1000, 133081 pairs so far)
#   Chunk [490000-500000]: Processed 9000/10000 galaxies (7095.1 gal/s, 0.1s for last 1000, 149576 pairs so far)
#   Chunk [490000-500000] COMPLETE: 10000 galaxies in 2.1s, found 16055 pairs
#
#   Checkpoint: Saved 1710992 pairs to data/paircatalogs/galaxy_pairs_catalog_CMASS_North_20_18_22hmpc_temp_50.csv
#   Chunk [500000-510000]: Processed 1000/10000 galaxies (5754.3 gal/s, 0.2s for last 1000, 15761 pairs so far)
#   Chunk [500000-510000]: Processed 2000/10000 galaxies (6452.5 gal/s, 0.2s for last 1000, 31746 pairs so far)
#   Chunk [500000-510000]: Processed 3000/10000 galaxies (7112.9 gal/s, 0.1s for last 1000, 47331 pairs so far)
#   Chunk [550000-560000]: Processed 6000/10000 galaxies (10342.6 gal/s, 0.1s for last 1000, 51654 pairs so far)
#   Chunk [550000-560000]: Processed 7000/10000 galaxies (11207.8 gal/s, 0.1s for last 1000, 59488 pairs so far)
#   Chunk [550000-560000]: Processed 8000/10000 galaxies (11294.2 gal/s, 0.1s for last 1000, 67460 pairs so far)
#   Chunk [550000-560000]: Processed 9000/10000 galaxies (11420.1 gal/s, 0.1s for last 1000, 75374 pairs so far)
#   Chunk [550000-560000] COMPLETE: 10000 galaxies in 1.2s, found 8251 pairs
#   Chunk [560000-570000]: Processed 1000/10000 galaxies (10571.0 gal/s, 0.1s for last 1000, 7502 pairs so far)
#   Chunk [560000-570000]: Processed 2000/10000 galaxies (12021.1 gal/s, 0.1s for last 1000, 14918 pairs so far)
#   Chunk [560000-570000]: Processed 3000/10000 galaxies (11749.9 gal/s, 0.1s for last 1000, 22101 pairs so far)
#   Chunk [560000-570000]: Processed 4000/10000 galaxies (11783.9 gal/s, 0.1s for last 1000, 28902 pairs so far)
#   Chunk [560000-570000]: Processed 5000/10000 galaxies (11998.6 gal/s, 0.1s for last 1000, 35626 pairs so far)
#   Chunk [560000-570000]: Processed 6000/10000 galaxies (12119.0 gal/s, 0.1s for last 1000, 42342 pairs so far)
#   Chunk [560000-570000]: Processed 7000/10000 galaxies (12669.6 gal/s, 0.1s for last 1000, 48972 pairs so far)
#   Chunk [560000-570000]: Processed 8000/10000 galaxies (13604.9 gal/s, 0.1s for last 1000, 55196 pairs so far)
#   Chunk [560000-570000]: Processed 9000/10000 galaxies (12525.7 gal/s, 0.1s for last 1000, 61540 pairs so far)
#   Chunk [560000-570000] COMPLETE: 10000 galaxies in 1.1s, found 6650 pairs
#   Chunk [570000-579089]: Processed 1000/9089 galaxies (12631.4 gal/s, 0.1s for last 1000, 6006 pairs so far)
#   Chunk [570000-579089]: Processed 2000/9089 galaxies (14556.5 gal/s, 0.1s for last 1000, 11725 pairs so far)
#   Chunk [570000-579089]: Processed 3000/9089 galaxies (13559.5 gal/s, 0.1s for last 1000, 17413 pairs so far)
#   Chunk [570000-579089]: Processed 4000/9089 galaxies (13059.4 gal/s, 0.1s for last 1000, 22671 pairs so far)
#   Chunk [570000-579089]: Processed 5000/9089 galaxies (17839.9 gal/s, 0.1s for last 1000, 26967 pairs so far)
#   Chunk [570000-579089]: Processed 6000/9089 galaxies (22312.5 gal/s, 0.0s for last 1000, 30423 pairs so far)
#   Chunk [570000-579089]: Processed 7000/9089 galaxies (24853.4 gal/s, 0.0s for last 1000, 32854 pairs so far)
#   Chunk [570000-579089]: Processed 8000/9089 galaxies (33685.9 gal/s, 0.0s for last 1000, 34437 pairs so far)
#   Chunk [570000-579089]: Processed 9000/9089 galaxies (30367.5 gal/s, 0.0s for last 1000, 35014 pairs so far)
#   Chunk [570000-579089] COMPLETE: 9089 galaxies in 0.6s, found 3486 pairs
#
# Found 1791569 total pairs
# Saved to data/paircatalogs/galaxy_pairs_catalog_CMASS_North_20_18_22hmpc.csv
# Total valid pairs: 1791569
